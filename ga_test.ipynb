# %%
from models.ga import GAConstraintLearner, iterate_vars, generate_library
from data.toy.toy_dataset import ToyDataset
# Out:
# pygame 2.6.1 (SDL 2.30.7, Python 3.9.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
library_of_predicates = generate_library('prolog/general_bias.pl', 4)

background_knowledge = "prolog/bk.pl"
pos_examples = []
neg_examples = []


target_idx = 1
trainset = ToyDataset('data', mode='graph', split='train')
for idx, data in enumerate(trainset):
    if data.z[target_idx] == 1:
        pos_examples.append(f'x{idx}_0')
    else:
        neg_examples.append(f'x{idx}_0')
    


# Create and run GA
ga = GAConstraintLearner(
    library_of_predicates=library_of_predicates,
    background_knowledge=background_knowledge,
    pos_examples=pos_examples,
    neg_examples=neg_examples,
    population_size=100,
    generations=20,
    elite_fraction=0.1,
    crossover_rate=0.8,
    mutation_rate=0.5,
    alpha=2.0,
    beta=1.0
)
best_gene, best_fit = ga()  # Calls the GA loop
print(f"BEST GENE: {best_gene}, FITNESS: {best_fit:.3f}")
# Out:
# holding 2
# not_holding 1
# on_top_of 2
# player 1
# empty_square 1
# wall 1
# knife 1
# tomato 1
# near 2
# move_to_able 1
# grab_able 1
# cut_able 1
# put_down_able 1
# whole_attr 1
# sliced_attr 1
# rule_0(A) :- near(B,A), whole_attr(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_1(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_2(A) :- near(D,C), near(B,D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_3(A) :- whole_attr(D), wall(A), holding(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_4(A) :- empty_square(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_5(A) :- cut_able(B), wall(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_6(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_7(A) :- holding(A,D), knife(D), whole_attr(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_8(A) :- near(A,B), cut_able(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_9(A) :- near(C,B), tomato(C), on_top_of(C,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_10(A) :- cut_able(D), wall(C), holding(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_11(A) :- wall(C), near(C,D), move_to_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_12(A) :- empty_square(B), on_top_of(D,A), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_13(A) :- holding(A,B)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_14(A) :- cut_able(A), holding(A,D), holding(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_15(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_16(A) :- tomato(B), holding(B,D), put_down_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_17(A) :- holding(A,B), put_down_able(D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_18(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_19(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_20(A) :- on_top_of(D,A), on_top_of(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_21(A) :- whole_attr(D), tomato(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_22(A) :- near(A,D), put_down_able(D), sliced_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_23(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_24(A) :- on_top_of(A,D), holding(C,D), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_25(A) :- wall(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_26(A) :- player(D), grab_able(C), on_top_of(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_27(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_28(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_29(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_30(A) :- on_top_of(B,D), holding(D,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_31(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_32(A) :- put_down_able(C), sliced_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_33(A) :- wall(D), whole_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_34(A) :- put_down_able(D), knife(A), on_top_of(D,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_35(A) :- holding(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_36(A) :- cut_able(C), wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_37(A) :- empty_square(B), on_top_of(A,D), on_top_of(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_38(A) :- tomato(A), on_top_of(D,C), tomato(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_39(A) :- empty_square(D), not_holding(D), tomato(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_40(A) :- holding(A,D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_41(A) :- sliced_attr(D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_42(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_43(A) :- move_to_able(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_44(A) :- on_top_of(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_45(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_46(A) :- whole_attr(D), near(B,D), holding(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_47(A) :- tomato(B), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_48(A) :- holding(D,C), holding(C,A), near(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_49(A) :- whole_attr(C), on_top_of(A,C), on_top_of(A,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_50(A) :- not_holding(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_51(A) :- knife(C), on_top_of(C,A), near(C,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_52(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_53(A) :- near(A,C), on_top_of(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_54(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_55(A) :- on_top_of(D,C), on_top_of(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_56(A) :- holding(D,A), holding(C,A), grab_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_57(A) :- on_top_of(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_58(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_59(A) :- not_holding(B), player(A), wall(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_60(A) :- near(D,B), holding(C,A), sliced_attr(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_61(A) :- whole_attr(B), near(B,A), put_down_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_62(A) :- whole_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_63(A) :- not_holding(B), player(C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_64(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_65(A) :- player(B), whole_attr(D), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_66(A) :- near(D,C), move_to_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_67(A) :- holding(B,D), whole_attr(A), wall(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_68(A) :- on_top_of(D,C), knife(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_69(A) :- on_top_of(A,D), near(D,B), holding(B,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_70(A) :- wall(A), knife(A), cut_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_71(A) :- holding(B,C), near(D,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_72(A) :- player(C), put_down_able(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_73(A) :- holding(B,C), whole_attr(D), holding(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_74(A) :- grab_able(D), on_top_of(B,A), on_top_of(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_75(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_76(A) :- wall(B), knife(D), on_top_of(C,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_77(A) :- wall(D), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_78(A) :- grab_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_79(A) :- sliced_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_80(A) :- holding(D,C), holding(B,D), on_top_of(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_81(A) :- on_top_of(D,C), holding(C,D), tomato(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_82(A) :- player(D), holding(C,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_83(A) :- tomato(C), cut_able(C), grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_84(A) :- holding(B,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_85(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_86(A) :- tomato(C), wall(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_87(A) :- player(D), grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_88(A) :- holding(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_89(A) :- wall(A), holding(B,A), not_holding(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_90(A) :- on_top_of(C,B), near(B,C), on_top_of(B,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_91(A) :- grab_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_92(A) :- whole_attr(D), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_93(A) :- player(B), holding(C,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_94(A) :- near(A,C), sliced_attr(D), whole_attr(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_95(A) :- wall(B), near(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_96(A) :- on_top_of(C,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_97(A) :- knife(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_98(A) :- knife(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_99(A) :- on_top_of(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# ======Gen 0: Best Fit = -0.695, Best Gene = ['<RULE>', 'near(C,D)', 'whole_attr(B)', 'empty_square(D)', '<RULE>'].
# rule_100(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_101(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_102(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_103(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_104(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_105(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_106(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_107(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_108(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_109(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_110(A) :- sliced_attr(B), tomato(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_111(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_112(A) :- sliced_attr(B), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_113(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_114(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_115(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_116(A) :- cut_able(A), holding(A,D), holding(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_117(A) :- move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_118(A) :- not_holding(B), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_119(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_120(A) :- tomato(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_121(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_122(A) :- near(D,C), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_123(A) :- empty_square(A), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_124(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_125(A) :- empty_square(D), not_holding(D), move_to_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_126(A) :- holding(B,A), near(A,B), tomato(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_127(A) :- wall(D), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_128(A) :- near(A,B), on_top_of(D,A), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_129(A) :- player(D), grab_able(C), sliced_attr(D), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_130(A) :- player(A), empty_square(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_131(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_132(A) :- sliced_attr(D), move_to_able(B), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_133(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_134(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_135(A) :- empty_square(B), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_136(A) :- near(A,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_137(A) :- on_top_of(B,D), holding(D,C), sliced_attr(D), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_138(A) :- cut_able(C), on_top_of(D,A), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_139(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_140(A) :- grab_able(D), cut_able(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_141(A) :- empty_square(D), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_142(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_143(A) :- near(A,D), not_holding(D), grab_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_144(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_145(A) :- put_down_able(C), not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_146(A) :- tomato(C), wall(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_147(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_148(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_149(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_150(A) :- holding(D,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_151(A) :- near(D,B), holding(C,A), sliced_attr(B), holding(B,C), on_top_of(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_152(A) :- near(A,B), move_to_able(D), tomato(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_153(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_154(A) :- whole_attr(D), holding(B,C), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_155(A) :- grab_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_156(A) :- near(B,A), whole_attr(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_157(A) :- cut_able(A), holding(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_158(A) :- empty_square(B), on_top_of(A,D), not_holding(B), on_top_of(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_159(A) :- sliced_attr(C), near(A,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_160(A) :- empty_square(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_161(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_162(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_163(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_164(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_165(A) :- holding(A,D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_166(A) :- holding(B,C), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_167(A) :- sliced_attr(A), grab_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_168(A) :- player(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_169(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_170(A) :- not_holding(D), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_171(A) :- not_holding(B), cut_able(A), holding(A,D), holding(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_172(A) :- near(A,D), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_173(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_174(A) :- on_top_of(C,D), empty_square(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_175(A) :- sliced_attr(C), on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_176(A) :- near(B,D), tomato(B), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_177(A) :- on_top_of(D,A), move_to_able(B), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_178(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_179(A) :- tomato(A), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_180(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_181(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_182(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_183(A) :- tomato(B), tomato(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_184(A) :- empty_square(D), near(B,A), not_holding(D), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_185(A) :- empty_square(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_186(A) :- sliced_attr(D), whole_attr(B), holding(D,C), cut_able(A), holding(A,D), holding(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_187(A) :- on_top_of(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_188(A) :- empty_square(B), wall(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# ======Gen 1: Best Fit = -0.695, Best Gene = ['<RULE>', 'near(C,D)', 'whole_attr(B)', 'empty_square(D)', '<RULE>'].
# rule_189(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_190(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_191(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_192(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_193(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_194(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_195(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_196(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_197(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_198(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_199(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_200(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_201(A) :- near(A,B), move_to_able(D), tomato(C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_202(A) :- empty_square(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_203(A) :- near(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_204(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_205(A) :- holding(C,D), whole_attr(C), move_to_able(D), tomato(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_206(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_207(A) :- holding(C,D), cut_able(A), holding(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_208(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_209(A) :- sliced_attr(C), holding(D,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_210(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_211(A) :- holding(B,C), near(B,A), not_holding(D), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_212(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_213(A) :- player(B), holding(A,D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_214(A) :- cut_able(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_215(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_216(A) :- cut_able(A), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_217(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_218(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_219(A) :- not_holding(D), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_220(A) :- player(D), grab_able(C), sliced_attr(D), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_221(A) :- holding(B,C), holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_222(A) :- sliced_attr(C), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_223(A) :- on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_224(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_225(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_226(A) :- sliced_attr(C), cut_able(A), holding(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_227(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_228(A) :- holding(B,C), move_to_able(D), near(A,D)
# TP: 246, TN: 7, FP: 572, FN: 8
# rule_229(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_230(A) :- holding(A,D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_231(A) :- holding(B,C), not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_232(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_233(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_234(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_235(A) :- near(D,B), holding(C,A), sliced_attr(B), holding(B,C), on_top_of(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_236(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_237(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_238(A) :- player(A), cut_able(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_239(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_240(A) :- sliced_attr(B), knife(B), not_holding(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_241(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_242(A) :- empty_square(B), wall(B), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_243(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_244(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_245(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_246(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_247(A) :- sliced_attr(C), holding(C,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_248(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_249(A) :- holding(B,C), player(D), grab_able(C), sliced_attr(D), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_250(A) :- holding(B,C), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_251(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_252(A) :- empty_square(B), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_253(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_254(A) :- near(C,B), wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_255(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_256(A) :- sliced_attr(C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_257(A) :- sliced_attr(D), player(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_258(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_259(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_260(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_261(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_262(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_263(A) :- holding(B,C), holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_264(A) :- sliced_attr(C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_265(A) :- holding(D,C), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_266(A) :- sliced_attr(C), knife(B), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_267(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_268(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_269(A) :- on_top_of(B,D), not_holding(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_270(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_271(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_272(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_273(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_274(A) :- move_to_able(B), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_275(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_276(A) :- holding(B,D), holding(A,D)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_277(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_278(A) :- sliced_attr(C), tomato(A), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# ======Gen 2: Best Fit = -0.695, Best Gene = ['<RULE>', 'near(C,D)', 'whole_attr(B)', 'empty_square(D)', '<RULE>'].
# rule_279(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_280(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_281(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_282(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_283(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_284(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_285(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_286(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_287(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_288(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_289(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_290(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_291(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_292(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_293(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_294(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_295(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_296(A) :- not_holding(C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_297(A) :- near(A,B), move_to_able(D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_298(A) :- holding(B,C), holding(B,C), move_to_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_299(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_300(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_301(A) :- holding(B,C), holding(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_302(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_303(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_304(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_305(A) :- near(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_306(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_307(A) :- holding(B,C), near(A,D), holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_308(A) :- holding(B,C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_309(A) :- holding(A,B)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_310(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_311(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_312(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_313(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_314(A) :- knife(A), near(A,B), move_to_able(D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_315(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_316(A) :- near(A,B), holding(B,C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_317(A) :- wall(C), near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_318(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_319(A) :- sliced_attr(C), whole_attr(D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# invalid gene, skipping
# rule_320(A) :- near(B,C), near(A,D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_321(A) :- player(A), on_top_of(C,A), put_down_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_322(A) :- empty_square(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_323(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_324(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_325(A) :- player(C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_326(A) :- near(D,A), player(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_327(A) :- sliced_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_328(A) :- holding(B,C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_329(A) :- holding(B,C), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_330(A) :- sliced_attr(C), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_331(A) :- move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_332(A) :- empty_square(B), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_333(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_334(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_335(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_336(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_337(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_338(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_339(A) :- holding(B,C), holding(B,C), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_340(A) :- sliced_attr(C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_341(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_342(A) :- player(A), cut_able(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_343(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_344(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_345(A) :- grab_able(D), holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_346(A) :- empty_square(B), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_347(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_348(A) :- holding(B,C), grab_able(C), on_top_of(D,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_349(A) :- near(D,A), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_350(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_351(A) :- not_holding(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_352(A) :- sliced_attr(D), player(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_353(A) :- sliced_attr(C), near(D,B), whole_attr(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_354(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_355(A) :- holding(C,D), player(A), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_356(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_357(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_358(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# invalid gene, skipping
# rule_359(A) :- holding(B,C), near(A,D), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_360(A) :- player(B), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_361(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_362(A) :- holding(B,C), empty_square(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_363(A) :- empty_square(B), wall(B), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_364(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_365(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_366(A) :- move_to_able(D), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# ======Gen 3: Best Fit = -0.695, Best Gene = ['<RULE>', 'near(C,D)', 'whole_attr(B)', 'empty_square(D)', '<RULE>'].
# rule_367(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_368(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_369(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_370(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_371(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_372(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_373(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_374(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_375(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_376(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_377(A) :- move_to_able(B), holding(B,C), holding(B,C), player(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_378(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_379(A) :- holding(C,D), on_top_of(C,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_380(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_381(A) :- knife(D), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_382(A) :- near(A,B), holding(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_383(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_384(A) :- holding(B,C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_385(A) :- move_to_able(D), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_386(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_387(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_388(A) :- player(B), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_389(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_390(A) :- player(C), near(A,D), move_to_able(D)
# TP: 246, TN: 7, FP: 572, FN: 8
# invalid gene, skipping
# rule_391(A) :- holding(B,C), holding(B,C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_392(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_393(A) :- wall(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_394(A) :- player(A), not_holding(D), player(B), empty_square(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# invalid gene, skipping
# rule_395(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_396(A) :- on_top_of(D,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_397(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_398(A) :- wall(B), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_399(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_400(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_401(A) :- move_to_able(C), holding(B,C), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_402(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_403(A) :- whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_404(A) :- put_down_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_405(A) :- holding(B,C), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_406(A) :- tomato(A), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_407(A) :- sliced_attr(B), on_top_of(A,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_408(A) :- player(B), wall(B), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_409(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_410(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_411(A) :- sliced_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_412(A) :- sliced_attr(C), whole_attr(D), holding(A,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_413(A) :- holding(B,C), near(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_414(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_415(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_416(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_417(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_418(A) :- player(B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_419(A) :- move_to_able(D), move_to_able(D), near(A,D)
# TP: 246, TN: 7, FP: 572, FN: 8
# rule_420(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_421(A) :- empty_square(C), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_422(A) :- grab_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_423(A) :- sliced_attr(C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_424(A) :- sliced_attr(C), whole_attr(D), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_425(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_426(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_427(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_428(A) :- wall(B), not_holding(D), player(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_429(A) :- on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_430(A) :- holding(B,C), holding(B,C), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_431(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_432(A) :- holding(B,C), wall(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_433(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_434(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_435(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_436(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_437(A) :- sliced_attr(C), holding(B,C), holding(D,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_438(A) :- player(C), near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_439(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_440(A) :- whole_attr(A), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_441(A) :- whole_attr(D), near(A,D), near(D,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_442(A) :- grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_443(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_444(A) :- wall(D), sliced_attr(C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_445(A) :- near(A,D), move_to_able(D)
# TP: 246, TN: 7, FP: 572, FN: 8
# rule_446(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_447(A) :- move_to_able(B), wall(C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_448(A) :- holding(B,C), near(A,D), holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_449(A) :- holding(B,C), near(A,D), near(A,B), on_top_of(C,A), move_to_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_450(A) :- on_top_of(C,A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_451(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_452(A) :- player(C), near(A,D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# ======Gen 4: Best Fit = 0.655, Best Gene = ['<RULE>', 'sliced_attr(C)', 'player(B)', 'not_holding(A)', '<RULE>'].
# rule_453(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_454(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_455(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_456(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_457(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_458(A) :- sliced_attr(D), whole_attr(B), put_down_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_459(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_460(A) :- near(A,B), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_461(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_462(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_463(A) :- move_to_able(D), move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_464(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_465(A) :- on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_466(A) :- on_top_of(D,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_467(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_468(A) :- sliced_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_469(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_470(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_471(A) :- on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_472(A) :- holding(B,C), holding(B,C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_473(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_474(A) :- empty_square(C), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_475(A) :- move_to_able(B), wall(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_476(A) :- put_down_able(D), near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_477(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_478(A) :- holding(B,C), whole_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_479(A) :- player(B), grab_able(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# invalid gene, skipping
# rule_480(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_481(A) :- near(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_482(A) :- empty_square(C), grab_able(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_483(A) :- grab_able(C), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_484(A) :- tomato(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_485(A) :- holding(B,C), move_to_able(D), wall(A), near(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_486(A) :- near(A,D), on_top_of(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_487(A) :- holding(B,C), holding(B,C), empty_square(B), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_488(A) :- holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_489(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_490(A) :- holding(C,D), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_491(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_492(A) :- on_top_of(B,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_493(A) :- sliced_attr(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_494(A) :- move_to_able(B), wall(C), near(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_495(A) :- sliced_attr(C), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_496(A) :- player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_497(A) :- holding(C,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_498(A) :- near(A,D), move_to_able(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_499(A) :- sliced_attr(C), player(B), not_holding(A), near(A,D)
# TP: 254, TN: 461, FP: 118, FN: 0
# invalid gene, skipping
# rule_500(A) :- sliced_attr(C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_501(A) :- holding(B,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_502(A) :- holding(B,C), holding(B,C), sliced_attr(C), grab_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# invalid gene, skipping
# rule_503(A) :- holding(B,C), empty_square(C), move_to_able(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_504(A) :- player(C), near(A,D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_505(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_506(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_507(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_508(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_509(A) :- near(A,D), empty_square(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_510(A) :- not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_511(A) :- sliced_attr(C), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_512(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# invalid gene, skipping
# rule_513(A) :- holding(B,C), holding(B,C), sliced_attr(C), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_514(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_515(A) :- grab_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_516(A) :- holding(D,C), holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_517(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_518(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_519(A) :- sliced_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_520(A) :- near(A,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_521(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_522(A) :- sliced_attr(C), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_523(A) :- put_down_able(A), whole_attr(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_524(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_525(A) :- player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_526(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_527(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_528(A) :- on_top_of(D,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_529(A) :- player(B), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_530(A) :- move_to_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_531(A) :- move_to_able(A), empty_square(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_532(A) :- holding(B,C), holding(B,C), not_holding(D), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_533(A) :- holding(D,A), move_to_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_534(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_535(A) :- near(A,B), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_536(A) :- wall(A), sliced_attr(C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_537(A) :- near(A,D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_538(A) :- wall(B), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_539(A) :- on_top_of(B,D), player(B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_540(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_541(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# invalid gene, skipping
# rule_542(A) :- empty_square(D), near(A,D)
# TP: 246, TN: 7, FP: 572, FN: 8
# ======Gen 5: Best Fit = 0.655, Best Gene = ['<RULE>', 'sliced_attr(C)', 'player(B)', 'not_holding(A)', '<RULE>'].
# rule_543(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_544(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_545(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_546(A) :- player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_547(A) :- sliced_attr(C), player(B), not_holding(A), near(A,D)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_548(A) :- not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_549(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_550(A) :- player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_551(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_552(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_553(A) :- empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_554(A) :- holding(B,C), holding(B,C), near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_555(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_556(A) :- cut_able(B), near(A,D), player(B), not_holding(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_557(A) :- empty_square(C), sliced_attr(C), player(B), not_holding(A), player(B), not_holding(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_558(A) :- wall(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_559(A) :- move_to_able(D), sliced_attr(C), player(B), not_holding(A), near(A,D)
# TP: 246, TN: 461, FP: 118, FN: 8
# rule_560(A) :- player(B), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_561(A) :- not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_562(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_563(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_564(A) :- near(A,D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_565(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_566(A) :- sliced_attr(C), holding(D,B), player(B), not_holding(A), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_567(A) :- holding(A,B), on_top_of(D,C)
# TP: 0, TN: 118, FP: 461, FN: 254
# rule_568(A) :- tomato(A), player(B), move_to_able(D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_569(A) :- move_to_able(D), holding(A,C), not_holding(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_570(A) :- on_top_of(A,B), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_571(A) :- near(A,B), near(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_572(A) :- sliced_attr(C), wall(A)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_573(A) :- sliced_attr(C), player(B), not_holding(A), wall(B), near(A,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_574(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_575(A) :- cut_able(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_576(A) :- player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_577(A) :- sliced_attr(C), whole_attr(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_578(A) :- sliced_attr(B), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_579(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_580(A) :- player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_581(A) :- sliced_attr(C), not_holding(A), near(A,D)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_582(A) :- sliced_attr(C), player(B), not_holding(A), near(A,D)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_583(A) :- holding(B,C), move_to_able(D), wall(A), near(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_584(A) :- sliced_attr(C), player(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_585(A) :- holding(B,C), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_586(A) :- player(B), not_holding(A), on_top_of(B,D)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_587(A) :- sliced_attr(C), holding(B,C), move_to_able(D), wall(A), not_holding(C), near(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# invalid gene, skipping
# rule_588(A) :- empty_square(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_589(A) :- holding(B,C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_590(A) :- holding(D,C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_591(A) :- player(A)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_592(A) :- near(C,D), whole_attr(B), empty_square(D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_593(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_594(A) :- sliced_attr(C), near(D,B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_595(A) :- sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_596(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_597(A) :- sliced_attr(C), player(B), not_holding(A), holding(B,C), move_to_able(D), wall(A), near(A,B)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_598(A) :- not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_599(A) :- sliced_attr(C), player(B), holding(B,C), holding(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_600(A) :- player(C), near(A,D), move_to_able(B)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_601(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_602(A) :- sliced_attr(C), player(B), not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_603(A) :- sliced_attr(C), sliced_attr(C)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_604(A) :- near(A,D)
# TP: 254, TN: 0, FP: 579, FN: 0
# rule_605(A) :- near(B,C), on_top_of(B,C)
# TP: 0, TN: 579, FP: 0, FN: 254
# rule_606(A) :- not_holding(A)
# TP: 254, TN: 461, FP: 118, FN: 0
# rule_607(A) :- player(B), sliced_attr(C), holding(A,B), not_holding(D), player(B)

# %%
gene = ['<RULE>', [True, 'on_top_of(C,B)'], 'AND', [True, 'near(A,B)'], 'AND', [True, 'not_holding(A)'], 'AND', [True, 'grab_able(C)'], '<RULE>']

#grab_affd(A):- on_top_of(C,B),near(A,B),not_holding(A),grab_able(C).

print(ga.fitness_function(gene))
# Out:
# rule_6(A) :- (on_top_of(C,B)), (near(A,B)), (not_holding(A)), (grab_able(C))
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TP: 254, TN: 579, FP: 0, FN: 0
# 1.0

# %%
arr = [1,2]
print(arr[1:])
print(arr[0:])
print(arr[:1])
print(arr[:2])
print(arr[:0])
# Out:
# [2]
# [1, 2]
# [1]
# [1, 2]
# []
