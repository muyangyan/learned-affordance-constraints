# %%
from models.ga import GAConstraintLearner, iterate_vars, generate_library
from data.toy_dataset import ToyDataset
# Out:
# pygame 2.6.1 (SDL 2.30.7, Python 3.9.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
library_of_predicates = generate_library('prolog/general_bias.pl', 4)

background_knowledge = "prolog/bk.pl"
pos_examples = []
neg_examples = []


target_idx = 2
trainset = ToyDataset('data', mode='graph', split='train')
for idx, data in enumerate(trainset):
    if data.z[target_idx] == 1:
        pos_examples.append(f'x{idx}_0')
    else:
        neg_examples.append(f'x{idx}_0')
    


# Create and run GA
ga = GAConstraintLearner(
    library_of_predicates=library_of_predicates,
    background_knowledge=background_knowledge,
    pos_examples=pos_examples,
    neg_examples=neg_examples,
    population_size=1000,
    generations=20,
    elite_fraction=0.1,
    crossover_rate=0.2,
    mutation_rate=0.9,
    alpha=2.0,
    beta=1.0
)
best_gene, best_fit = ga()  # Calls the GA loop
print(f"BEST GENE: {best_gene}, FITNESS: {best_fit:.3f}")
# Out:
# holding 2
# not_holding 1
# on_top_of 2
# player 1
# empty_square 1
# wall 1
# knife 1
# tomato 1
# near 2
# move_to_able 1
# grab_able 1
# cut_able 1
# put_down_able 1
# whole_attr 1
# sliced_attr 1
# rule_0(A) :- (\+ on_top_of(C,A); \+ grab_able(A)), (\+ knife(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_1(A) :- (near(D,B))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_2(A) :- (near(C,B)), (not_holding(D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_3(A) :- (\+ holding(D,B); \+ holding(B,D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_4(A) :- (on_top_of(A,C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_5(A) :- (\+ holding(B,C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_6(A) :- (holding(B,D)), (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_7(A) :- (on_top_of(B,A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_8(A) :- (\+ wall(D)), (tomato(C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_9(A) :- (\+ move_to_able(A); cut_able(C))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_10(A) :- (near(C,A)), (\+ near(C,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_11(A) :- (grab_able(A); empty_square(A); \+ knife(C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_12(A) :- (\+ on_top_of(A,B); \+ cut_able(A); empty_square(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_13(A) :- (near(B,A)), (near(B,A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_14(A) :- (on_top_of(C,A)), (\+ on_top_of(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_15(A) :- (\+ on_top_of(C,D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_16(A) :- (\+ sliced_attr(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_17(A) :- (cut_able(B)), (\+ put_down_able(C); tomato(C))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_18(A) :- (\+ tomato(C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_19(A) :- (knife(A)), (near(B,D)), (empty_square(C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_20(A) :- (holding(D,C)), (not_holding(C))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_21(A) :- (knife(B)), (\+ not_holding(B)), (\+ wall(B))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_22(A) :- (holding(B,D); \+ near(D,A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_23(A) :- (\+ grab_able(D); \+ not_holding(D); \+ holding(A,C))
# TP: 0, TN: 325, FP: 372, FN: 136
# rule_24(A) :- (\+ sliced_attr(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_25(A) :- (\+ wall(B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_26(A) :- (\+ cut_able(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_27(A) :- (not_holding(C)), (knife(D)), (on_top_of(A,D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_28(A) :- (\+ on_top_of(A,D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_29(A) :- (\+ wall(C)), (player(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# ======Gen 0: Best Fit = -0.837, Best Gene = ['<RULE>', [False, 'near(D,B)'], '<RULE>'].
# rule_30(A) :- (near(D,B))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_31(A) :- (near(C,B)), (not_holding(D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_32(A) :- (\+ move_to_able(A); cut_able(C))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_33(A) :- (\+ near(C,B)), (\+ not_holding(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_34(A) :- (near(B,D)), (\+ cut_able(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_35(A) :- (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_36(A) :- (near(A,D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_37(A) :- (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_38(A) :- (\+ move_to_able(A); \+ cut_able(C))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_39(A) :- (holding(B,A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_40(A) :- (\+ near(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_41(A) :- (\+ near(D,B); \+ holding(C,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_42(A) :- (holding(B,D)), (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_43(A) :- (cut_able(D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_44(A) :- (\+ on_top_of(C,A)), (\+ wall(D)), (\+ on_top_of(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_45(A) :- (holding(B,D)), (\+ near(D,A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_46(A) :- (\+ near(C,B)), (\+ not_holding(D); near(A,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_47(A) :- (\+ wall(C)), (player(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_48(A) :- (\+ near(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# invalid gene, skipping
# rule_49(A) :- (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_50(A) :- (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_51(A) :- (\+ not_holding(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_52(A) :- (sliced_attr(A))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_53(A) :- (\+ cut_able(A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_54(A) :- (\+ on_top_of(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_55(A) :- (\+ on_top_of(C,A))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_56(A) :- (\+ near(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_57(A) :- (\+ near(D,B))
# TP: 0, TN: 697, FP: 0, FN: 136
# rule_58(A) :- (\+ near(C,B)), (\+ not_holding(D))
# TP: 0, TN: 697, FP: 0, FN: 136
# ======Gen 1: Best Fit = -0.837, Best Gene = ['<RULE>', [True, 'near(D,B)'], '<RULE>'].
# rule_59(A) :- (near(D,B))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_60(A) :- (near(C,B)), (not_holding(D))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_61(A) :- (\+ move_to_able(A); cut_able(C))
# TP: 136, TN: 0, FP: 697, FN: 0
# rule_62(A) :- (near(B,D)), (cut_able(A))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      18 # Create and run GA
#      19 ga = GAConstraintLearner(
#      20     library_of_predicates=library_of_predicates,
#      21     background_knowledge=background_knowledge,
#    (...)
#      30     beta=1.0
#      31 )
# ---> 32 best_gene, best_fit = ga()  # Calls the GA loop
#      33 print(f"BEST GENE: {best_gene}, FITNESS: {best_fit:.3f}")
#
# File ~/learned-affordance-constraints/models/ga.py:283, in GAConstraintLearner.__call__(self)
#     281 self.population = self.init_population()                                                    # Initialize population.
#     282 for gen in range(self.generations):
# --> 283     self.fitness_scores = [self.fitness_function(g) for g in self.population]               # Evaluate fitness.
#     284     best_idx = max(range(len(self.population)), key=lambda i: self.fitness_scores[i])
#     285     best_gene = self.population[best_idx]
#
# File ~/learned-affordance-constraints/models/ga.py:283, in <listcomp>(.0)
#     281 self.population = self.init_population()                                                    # Initialize population.
#     282 for gen in range(self.generations):
# --> 283     self.fitness_scores = [self.fitness_function(g) for g in self.population]               # Evaluate fitness.
#     284     best_idx = max(range(len(self.population)), key=lambda i: self.fitness_scores[i])
#     285     best_gene = self.population[best_idx]
#
# File ~/learned-affordance-constraints/models/ga.py:168, in GAConstraintLearner.fitness_function(self, gene)
#     166 total = total_pos + total_neg
#     167 for ex in self.pos:
# --> 168     is_true = self.evaluate_gene(self.rule_id, ex)   # Evaluate classification: does 'gene' say "True" for this ex?
#     169     if is_true:
#     170         tp += 1
#
# File ~/learned-affordance-constraints/models/ga.py:201, in GAConstraintLearner.evaluate_gene(self, rule_id, example)
#     195 #q = self.prolog.query(f'rule_%d({example})' % rule_id, maxresult=1)
#     196 #for solution in q:
#     197 #    q.close()
#     198 #    return True
#     200 q = self.prolog.query(f'rule_%d({example})' % rule_id, maxresult=1)
# --> 201 for solution in q:
#     202     return True
#     203 return False
#
# File ~/miniconda3/envs/ilp/lib/python3.9/site-packages/pyswip/prolog.py:152, in Prolog._QueryWrapper.__call__(self, query, maxresult, catcherrors, normalize)
#     150 Prolog._queryIsOpen = True  # From now on, the query will be considered open
#     151 try:
# --> 152     while maxresult and PL_next_solution(swipl_qid):
#     153         maxresult -= 1
#     154         swipl_list = PL_copy_term_ref(swipl_bindingList)
#
# KeyboardInterrupt:

# %%
gene = ['<RULE>', [True, 'on_top_of(C,B)'], 'AND', [True, 'near(A,B)'], 'AND', [True, 'not_holding(A)'], 'AND', [True, 'grab_able(C)'], '<RULE>']

#grab_affd(A):- on_top_of(C,B),near(A,B),not_holding(A),grab_able(C).

print(ga.fitness_function(gene))
# Out:
# rule_6(A) :- (on_top_of(C,B)), (near(A,B)), (not_holding(A)), (grab_able(C))
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TP
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TN
# TP: 254, TN: 579, FP: 0, FN: 0
# 1.0

# %%
arr = [1,2]
print(arr[1:])
print(arr[0:])
print(arr[:1])
print(arr[:2])
print(arr[:0])
# Out:
# [2]
# [1, 2]
# [1]
# [1, 2]
# []
